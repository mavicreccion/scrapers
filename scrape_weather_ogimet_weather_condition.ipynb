# %%
from lxml import html
import requests
import pandas as pd
import datetime
from datedelta import datedelta
import re

# %%
def addMonths(date, numMonths):
    return date + datedelta(months=numMonths)

# %%
def addDays(date, numDays):
    return date + datedelta(days=numDays)

# %%
def text(elt):
    return elt.text_content().replace(u'\xa0', u' ')

# %%
def countRemainingDays(prev_date):
    next_year = prev_date.year + 1
    curr_date = prev_date
    while (curr_date.year < next_year):
        curr_date = curr_date + datedelta(days=1)
    temp_date = curr_date - datedelta(days=1)
    remaining_days = temp_date.day - prev_date.day + 1
    return remaining_days, curr_date

# %%
def getData(root, index):
    # retrieve table
    table = root.xpath('//table[@bgcolor="#d0d0d0"]')[0]

    headers = ['Date', 'Caption', 'Subcaption']

    data = []
    length = len(table.xpath('//thead/tr'))

    for i in range(2, length):
        tr = table.xpath('//thead/tr['+str(i)+']')
        date = text(tr[0].xpath('td[1]')[0])
        hour = text(tr[0].xpath('td[2]')[0])

        # merge date and time
        row_datetime = datetime.datetime.strptime(date + ' ' + hour, '%m/%d/%Y %H:%M')
        
        if(index < 18):
            image = tr[0].xpath('td[16]/img/@onmouseover')[0]
        else:
            image = tr[0].xpath('td[17]/img/@onmouseover')[0]
            
        splitImage = re.split(" overlib\('|',CAPTION,'|'\); ", image)
        row_caption = splitImage[2]
        row_subcaption = splitImage[1]

        row = []
        row.append(row_datetime)
        row.append(row_caption)
        row.append(row_subcaption)

        data.append(row)

    data = pd.DataFrame(data, columns=headers)
    return data

# %%
curr_date = datetime.date(2015, 1, 1)
end_of_year = False
data_list = []
for i in range(0,24):
    
    # 1. preparing the URL
    remaining_days = 50
    
    if(end_of_year == True):
        days_date = countRemainingDays(curr_date)
        remaining_days = days_date[0]
        curr_date = days_date[1]
        end_of_year = False
    else:
        curr_date = addDays(curr_date, remaining_days) 
    
    URL = 'http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=' + str(remaining_days) + '&ano=' + str(curr_date.year) + '&mes=' + str(curr_date.month) + '&day=' + str(curr_date.day) + '&hora=00'
    print(URL)
    
    # 2. get the html data from website
    page = requests.get(URL)
    root = html.fromstring(page.content)
    
    # 3. get data from html
    data = getData(root,i)
    
    if(i in [6, 14, 22]):
        i = i - 1
        end_of_year = True
        
    # 4. remove excess first row
    if(i not in [7, 15]):
        data = data.drop(data.index[0])
        
    # 5. reverse data frame order
    data = data.iloc[::-1]
        
    # 6. add to list of df
    data_list.append(data)
# Out:
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=2&day=20&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=4&day=11&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=5&day=31&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=7&day=20&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=9&day=8&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=10&day=28&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2015&mes=12&day=17&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=15&ano=2016&mes=1&day=1&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=2&day=20&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=4&day=10&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=5&day=30&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=7&day=19&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=9&day=7&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=10&day=27&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2016&mes=12&day=16&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=16&ano=2017&mes=1&day=1&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=2&day=20&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=4&day=11&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=5&day=31&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=7&day=20&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=9&day=8&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays=50&ano=2017&mes=10&day=28&hora=00
# http://www.ogimet.com/cgi-bin/gsynres?lang=en&ind=98425&decoded=yes&ndays
# 8672          Overcast. Night. At 12/31/2017 21:00 UTC
#
# [8673 rows x 3 columns]

# %%
weather_data = pd.read_csv('weather_ogimet_2015_2016_2017.csv')

condition_data = pd.read_csv('weather_ogimet_2015_2016_2017_weathercondition.csv')
condition_data
# Out:
#                   Date                                            Caption  \
# 0        1/1/2015 3:00  Present weather reported from a manned weather...
# 1        1/1/2015 6:00  Present weather reported from a manned weather...
# 2        1/1/2015 9:00  Present weather reported from a manned weather...
# 3       1/1/2015 12:00  Present weather reported from a manned weather...
# 4       1/1/2015 15:00  Present weather reported from a manned weather...
# 5       1/1/2015 18:00  Present weather reported from a manned weather...
# 6       1/1/2015 21:00  Present weather reported from a manned weather...
# 7        1/2/2015 0:00  Present weather reported from a manned weather...
# 8        1/2/2015 3:00  Present weather reported from a manned weather...
# 9        1/2/2015 6:00  Present weather reported from a manned weather...
# 10       1/2/2015 9:00  Present weather reported from a manned weather...
# 11      1/2/2015 12:00  Present weather reported from a manned weather...
# 12      1/2/2015 15:00  Present weather reported from a manned weather...
# 13      1/2/2015 18:00  Present weather reported from a manned weather...
# 14      1/2/2015 21:00  Present weather reported from a manned weather...
# 15       1/3/2015 0:00  Present weather reported from a manned weather...
# 16       1/3/2015 3:00  Present weather reported from a manned weather...
# 17       1/3/2015 6:00  Present weather reported from a manned weather...
# 18       1/3/2015 9:00  Present weather reported from a manned weather...
# 19      1/3/2015 12:00  Present weather reported from a manned weather...
# 20      1/3/2015 15:00  Present weather reported from a manned weather...
# 21      1/3/2015 18:00  Present weather reported from a manned weather...
# 22      1/3/2015 21:00  Present weather reported from a manned weather...
# 23       1/4/2015 0:00  Present weather reported from a manned weather...
# 24       1/4/2015 3:00  Present weather reported from a manned weather...
# 25       1/4/2015 6:00  Present weather reported from a manned weather...
# 26       1/4/2015 9:00  Present weather reported from a manned weather...
# 27      1/4/2015 12:00  Present weather reported from a manned weather...
# 28      1/4/2015 15:00  Present weather reported from a manned weather...
# 29      1/4/2015 18:00                       No WW data. Ogimet extension
# ...                ...                                                ...
# 8643   12/28/2017 6:00  Present weather reported from a manned weather...
# 8644   12/28/2017 9:00  Present weather reported from a manned weather...
# 8645  12/28/2017 12:00  Present weather reported from a manned weather...
# 8646  12/28/2017 15:00                       No WW data. Ogimet extension
# 8647  12/28/2017 18:00                       No WW data. Ogimet extension
# 8648  12/28/2017 21:00                       No WW data. Ogimet extension
# 8649   12/29/2017 0:00  Present weather reported from a manned weather...
# 8650   12/29/2017 3:00  Present weather reported from a manned weather...
# 8651   12/29/2017 6:00  Present weather reported from a manned weather...
# 8652   12/29/2017 9:00  Present weather reported from a manned weather...
# 8653  12/29/2017 12:00  Present weather reported from a manned weather...
# 8654  12/29/2017 15:00                       No WW data. Ogimet extension
# 8655  12/29/2017 18:00                       No WW data. Ogimet extension
# 8656  12/29/2017 21:00                       No WW data. Ogimet extension
# 8657   12/30/2017 0:00  Present weather reported from a manned weather...
# 8658   12/30/2017 3:00  Present weather reported from a manned weather...
# 8659   12/30/2017 6:00  Present weather reported from a manned weather...
# 8660   12/30/2017 9:00  Present weather reported from a manned weather...
# 8661  12/30/2017 12:00  Present weather reported from a manned weather...
# 8662  12/30/2017 15:00                       No WW data. Ogimet extension
# 8663  12/30/2017 18:00                       No WW data. Ogimet extension
# 8664  12/30/2017 21:00                       No WW data. Ogimet extension
# 8665   12/31/2017 0:00  Present weather reported from a manned weather...
# 8666   12/31/2017 3:00  Present weather reported from a manned weather...
# 8667   12/31/2017 6:00  Present weather reported from a manned weather...
# 8668   12/31/2017 9:00  Present weather reported from a manned weather...
# 8669  12/31/2017 12:00  Present weather reported from a manned weather...
# 8670  12/31/2017 15:00                       No WW data. Ogimet extension
# 8671  12/31/2017 18:00                       No WW data. Ogimet extension
# 8672  12/31/2017 21:00                       No WW data. Ogimet extension
#
#                                              Subcaption
# 0                                                  Haze
# 1     Rain, not freezing, continuous, slight at time...
# 2                                Rain shower(s), slight
# 3                                                  Haze
# 4     State of sky on the whole unchanged. No meteor...
# 5     Clouds generally dissolving or becoming less d...
# 6     Clouds generally dissolving or becoming less d...
# 7                                                  Haze
# 8                                                  Haze
# 9                                                  Haze
# 10                                                 Haze
# 11                                                 Haze
# 12    State of sky on the whole unchanged. No meteor...
# 13    Clouds generally forming or developing. No met...
# 14    Clouds generally forming or developing. No met...
# 15                                                 Haze
# 16                                                 Haze
# 17                                                 Haze
# 18                                                 Haze
# 19                                                 Haze
# 20    State of sky on the whole unchanged. No meteor...
# 21    Clouds generally dissolving or becoming less d...
# 22    Clouds generally forming or developing. No met...
# 23                                                 Haze
# 24                                                 Haze
# 25                                                 Haze
# 26                                                 Haze
# 27                                                 Haze
# 28    Clouds generally dissolving or becoming less d...
# 29            Overcast. Night. At 01/04/2015 18:00 UTC
# ...                                                 ...
# 8643                                               Haze
# 8644                                               Haze
# 8645                                               Haze
# 8646          Overcast. Night. At 12/28/2017 15:00 UTC
# 8647          Overcast. Night. At 12/28/2017 18:00 UTC
# 8648          Overcast. Night. At 12/28/2017 21:00 UTC
# 8649                                               Haze
# 8650                                               Haze
# 8651                                               Haze
# 8652                                               Haze
# 8653                                               Haze
# 8654            Broken. Night. At 12/29/2017 15:00 UTC
# 8655            Broken. Night. At 12/29/2017 18:00 UTC
# 8656            Broken. Night. At 12/29/2017 21:00 UTC
# 8657                                               Haze
# 8658                                               Haze
# 8659                                               Haze
# 8660                                               Haze
# 8661                                               Haze
# 8662            Broken. Night. At 12/30/2017 15:00 UTC
# 8663            Broken. Night. At 12/30/2017 18:00 UTC
# 8664            Broken. Night. At 12/30/2017 21:00 UTC
# 8665                                               Haze
# 8666                                               Haze
# 8667                                               Haze
# 8668                                               Haze
# 8669                                               Haze
# 8670            Broken. Night. At 12/31/2017 15:00 UTC
# 8671          Overcast. Night. At 12/31/2017 18:00 UTC
# 8672          Overcast. Night. At 12/31/2017 21:00 UTC
#
# [8673 rows x 3 columns]

# %%
compiled_data = pd.merge(weather_data, condition_data, on='Date')
compiled_data.to_csv('weather_ogimet_2015_2016_2017_compiled.csv')
